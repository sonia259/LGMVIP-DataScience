# %% [markdown]
# ## LetsGrowMore
# ### Name: Sonia Tripathi
# ### LGM_Task4

# %% [markdown]
# ### Exploratory Data Analysis on Terrorism Dataset

# %% [markdown]
# ### Problem Statement
#
# - Here, we are trying to perform an Exploratory Data Analytics to find the most affected countries,states and city. Also,to find the hot zone for terrorism. Weapons that they used and so on.

# %% [markdown]
# ### IMPORT STATEMENTS

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize']=[15,8]

# %% [markdown]
# ### Read Data

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
print("The first five observations in the dataset :")
df.head()
# Out:
# The first five observations in the dataset :
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
print("The last five observations in the dataset :")
df.tail()
# Out:
# The last five observations in the dataset :
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ### Data Dimension

# %%
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# - There are 181691 observations and 135 attributes in our dataset.

# %% [markdown]
# ### Checking for the Data Types

# %%
df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %% [markdown]
# - Since there are around 135 columns it is difficult to go through all and find if all the data types are identified correctly.

# %% [markdown]
# ### 5 point summary

# %%
# for numerical columns
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# - from the above output, we can infer that :
#     - there are few missing values since the count values for each of column is different.
#     - 5 point summary(min,25%,50%,75%,max), mean and Standard devation for different numerical variables can be seen.

# %%
# for categorical columns
df.describe(include=object)
# Out:
#                    approxdate resolution country_txt  \
# count                    9239       2220      181691
# unique                   2244       1859         205
# top     September 18-24, 2016   8/4/1998        Iraq
# freq                      101         18       24636
#
#                         region_txt provstate     city  \
# count                       181691    181270   181257
# unique                          12      2855    36674
# top     Middle East & North Africa   Baghdad  Unknown
# freq                         50474      7645     9775
#
#                                                 location  \
# count                                              55495
# unique                                             44109
# top     The attack took place in Baghdad, Baghdad, Iraq.
# freq                                                 142
#
#                                                   summary  \
# count                                              115562
# unique                                             112492
# top     09/00/2016: Sometime between September 18, 201...
# freq                                                  100
#
#                    alternative_txt    attacktype1_txt  ...   divert  \
# count                        29011             181691  ...      324
# unique                           5                  9  ...      143
# top     Insurgency/Guerilla Action  Bombing/Explosion  ...  Unknown
# freq                         23410              88255  ...       27
#
#        kidhijcountry ransomnote hostkidoutcome_txt  \
# count           3305        514              10991
# unique           217        387                  7
# top         Colombia          0            Unknown
# freq             687         36               3606
#
#                                                  addnotes  \
# count                                               28289
# unique                                              15429
# top     Casualty numbers for this incident conflict ac...
# freq                                                 1607
#
#                                                    scite1  \
# count                                              115500
# unique                                              83988
# top     Committee on Government Operations United Stat...
# freq                                                  205
#
#                                                    scite2  \
# count                                               76933
# unique                                              62263
# top     Christopher Hewitt, "Political Violence and Te...
# freq                                                  134
#
#                                                    scite3  \
# count                                               43516
# unique                                              36090
# top     Christopher Hewitt, "Political Violence and Te...
# freq                                                  139
#
#                         dbsource  \
# count                     181691
# unique                        26
# top     START Primary Collection
# freq                       78002
#
#                                                   related
# count                                               25038
# unique                                              14306
# top     201612010023, 201612010024, 201612010025, 2016...
# freq                                                   80
#
# [4 rows x 58 columns]

# %% [markdown]
# - from the above output, we can infer that :
#     - there are few missing values since the count values for each of column is different.
#     - there are 12 different regions and Middle East and North Africa has the highest frequency with count 50474.
#     - most of the approxdate is on September 18-24 2016.
#     - as of now, country Iraq has the highest terrorism rate with count of 24636

# %% [markdown]
# ### Data Cleaning

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','attacktype1_txt':'Attacktype','targtype1_txt':'Target_type','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %% [markdown]
# ### Checking for null values and treating them.

# %%
Total = df.isnull().sum().sort_values(ascending=False) 
Percent = (df.isnull().sum()*100/df.isnull().count()).sort_values(ascending=False)   
missing_data = pd.concat([Total, Percent], axis = 1, keys = ['Total', 'Percentage of Missing Values'])
missing_data
# Out:
#                    Total  Percentage of Missing Values
# gsubname3         181671                     99.988992
# weapsubtype4_txt  181621                     99.961473
# weapsubtype4      181621                     99.961473
# weaptype4         181618                     99.959822
# weaptype4_txt     181618                     99.959822
# ...                  ...                           ...
# attacktype1            0                      0.000000
# suicide                0                      0.000000
# success                0                      0.000000
# crit3                  0                      0.000000
# eventid                0                      0.000000
#
# [135 rows x 2 columns]

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# - Now since there are many columns, also if the percentage of missing values is more than 80 %, let us eliminate that column as it wont help our analysis since most of the values are unknown.

# %% [markdown]
# #### Dropping columns having more than 80% of missing values since they are insignificant

# %%
for idx, x in missing_data['Percentage of Missing Values'].iteritems():
    if x  > 80 : 
        df=df.drop(idx,1)

# %% [markdown]
# - Now that we have dropped the columns that contains, missing values more than 80 %, let us see how many columns and there percentage of missing values.

# %%
Total = df.isnull().sum().sort_values(ascending=False) 
Percent = (df.isnull().sum()*100/df.isnull().count()).sort_values(ascending=False)   
missing_data = pd.concat([Total, Percent], axis = 1, keys = ['Total', 'Percentage of Missing Values'])
missing_data
# Out:
#               Total  Percentage of Missing Values
# propvalue    142702                     78.541039
# scite3       138175                     76.049447
# motive       131130                     72.171984
# location     126196                     69.456385
# propcomment  123732                     68.100236
# ...             ...                           ...
# Attacktype        0                      0.000000
# attacktype1       0                      0.000000
# suicide           0                      0.000000
# success           0                      0.000000
# eventid           0                      0.000000
#
# [67 rows x 2 columns]

# %% [markdown]
# - We see that most of the columns have been dropped indicating that our data had more unknown values, now we shall try filling the missing values of remaining columns.

# %%
missing_data['Type'] = df[missing_data.index].dtypes

# %%
missing_data
# Out:
#               Total  Percentage of Missing Values     Type
# propvalue    142702                     78.541039  float64
# scite3       138175                     76.049447   object
# motive       131130                     72.171984   object
# location     126196                     69.456385   object
# propcomment  123732                     68.100236   object
# ...             ...                           ...      ...
# Attacktype        0                      0.000000   object
# attacktype1       0                      0.000000    int64
# suicide           0                      0.000000    int64
# success           0                      0.000000    int64
# eventid           0                      0.000000    int64
#
# [67 rows x 3 columns]

# %%
df[df['State']=='Unknown']
# Out:
#              eventid  Year  Month  day  extended  country      Country  \
# 16      197001110001  1970      1   11         0       65     Ethiopia
# 103     197003030001  1970      3    3         0      185        Spain
# 132     197003140001  1970      3   14         1       65     Ethiopia
# 165     197004000001  1970      4    0         1       65     Ethiopia
# 210     197004210001  1970      4   21         0      160  Philippines
# ...              ...   ...    ...  ...       ...      ...          ...
# 180885  201711280046  2017     11   28         1       37     Cameroon
# 181112  201712060033  2017     12   11         0       95         Iraq
# 181300  201712130030  2017     12   13         0      209       Turkey
# 181351  201712160030  2017     12   16         1      200        Syria
# 181542  201712250031  2017     12   25         1       42         Chad
#
#         region                      Region    State  ... ishostkid  ransom  \
# 16          11          Sub-Saharan Africa  Unknown  ...       0.0     0.0
# 103          8              Western Europe  Unknown  ...       1.0     1.0
# 132         11          Sub-Saharan Africa  Unknown  ...       1.0     1.0
# 165         11          Sub-Saharan Africa  Unknown  ...       1.0     0.0
# 210          5              Southeast Asia  Unknown  ...       0.0     0.0
# ...        ...                         ...      ...  ...       ...     ...
# 180885      11          Sub-Saharan Africa  Unknown  ...       1.0     0.0
# 181112      10  Middle East & North Africa  Unknown  ...       0.0     NaN
# 181300      10  Middle East & North Africa  Unknown  ...       0.0     NaN
# 181351      10  Middle East & North Africa  Unknown  ...       1.0     0.0
# 181542      11          Sub-Saharan Africa  Unknown  ...      -9.0     NaN
#
#                                                    scite1  \
# 16                                                    NaN
# 103                                                   NaN
# 132                                                   NaN
# 165                                                   NaN
# 210                                                   NaN
# ...                                                   ...
# 180885  "Military Launches Operation to Free Hostages,...
# 181112  "Section of Iraq-Turkey pipeline cleared from ...
# 181300  "Turkey: Civilian succumbs to injuries after P...
# 181351  "Mother, held in Syria after trying to bring s...
# 181542  "Sudanese gold miners killed in Chad attack," ...
#
#                                                    scite2  \
# 16                                                    NaN
# 103                                                   NaN
# 132                                                   NaN
# 165                                                   NaN
# 210                                                   NaN
# ...                                                   ...
# 180885                                                NaN
# 181112                                                NaN
# 181300                                                NaN
# 181351  "Jolly Bimbachi, mother held by al-Qaeda affil...
# 181542  "Sudanese Gold Miners Killed In Chad Attack," ...
#
#                                                    scite3  \
# 16                                                    NaN
# 103                                                   NaN
# 132                                                   NaN
# 165                                                   NaN
# 210                                                   NaN
# ...                                                   ...
# 180885                                                NaN
# 181112                                                NaN
# 181300                                                NaN
# 181351  "Syria raids kill 30 near Damascus as war of w...
# 181542                                                NaN
#
#                         dbsource INT_LOG  INT_IDEO  INT_MISC  INT_ANY
# 16                          PGIS       0         1         1        1
# 103                         PGIS       0         1         0        1
# 132                         PGIS       0         1         1        1
# 165                         PGIS       0         1         1        1
# 210                         PGIS      -9        -9         0       -9
# ...                          ...     ...       ...       ...      ...
# 180885  START Primary Collection      -9        -9         0       -9
# 181112  START Primary Collection       0         1         0        1
# 181300  START Primary Collection       0         0         0        0
# 181351  START Primary Collection      -9        -9         1        1
# 181542  START Primary Collection      -9        -9         0       -9
#
# [4290 rows x 67 columns]

# %% [markdown]
# - we see that there are unknown values in State column and maybe in other columns as well. Hence, we shall replace unknown with nan and then do the missing value treatment

# %%
df.replace(to_replace ="Unknown",value =np.nan,inplace=True)

# %%
dfTotal = df.isnull().sum().sort_values(ascending=False) 
Percent = (df.isnull().sum()*100/df.isnull().count()).sort_values(ascending=False)   
missing_data = pd.concat([Total, Percent], axis = 1, keys = ['Total', 'Percentage of Missing Values'])
missing_data['Type'] = df[missing_data.index].dtypes
missing_data
# Out:
#               Total  Percentage of Missing Values     Type
# propvalue    142702                     78.541039  float64
# scite3       138175                     76.049447   object
# motive       131130                     80.366666   object
# location     126196                     69.465191   object
# propcomment  123732                     68.100787   object
# ...             ...                           ...      ...
# Attacktype        0                      4.004601   object
# attacktype1       0                      0.000000    int64
# suicide           0                      0.000000    int64
# success           0                      0.000000    int64
# eventid           0                      0.000000    int64
#
# [67 rows x 3 columns]

# %% [markdown]
# -
#     - Seperating object datatype and other datatypes.

# %%
obj=[]
num=[]
for idx, x in missing_data['Type'].iteritems():

    idx=str(idx)
    if x=='object' :
        obj.append(idx)
    else:
        num.append(idx)
print('Categorical type: ',obj,'\n')   
print('Numerical type',num)
# Out:
# Categorical type:  ['scite3', 'motive', 'location', 'propcomment', 'propextent_txt', 'scite2', 'weapdetail', 'scite1', 'summary', 'corp1', 'weapsubtype1_txt', 'targsubtype1_txt', 'natlty1_txt', 'target1', 'city', 'State', 'Country', 'Region', 'dbsource', 'Weapon', 'Group', 'Target_type', 'Attacktype']
#
# Numerical type ['propvalue', 'propextent', 'ransom', 'nperps', 'nperpcap', 'nwoundte', 'nkillter', 'claimed', 'nwoundus', 'nkillus', 'weapsubtype1', 'Wound', 'targsubtype1', 'kill', 'longitude', 'latitude', 'natlty1', 'guncertain1', 'ishostkid', 'specificity', 'multiple', 'doubtterr', 'crit1', 'extended', 'region', 'day', 'Month', 'vicinity', 'Year', 'country', 'INT_ANY', 'crit2', 'crit3', 'INT_IDEO', 'INT_LOG', 'property', 'weaptype1', 'individual', 'INT_MISC', 'targtype1', 'attacktype1', 'suicide', 'success', 'eventid']

# %% [markdown]
# -
#     - filling the nan values with the mode of each categorical column because that is the most repeated value

# %%
df[obj]=df[obj].fillna(df.mode().iloc[0])

# %% [markdown]
# ### Checking for outliers of numerical columns to handle missing values using a boxplot

# %%
df[num].boxplot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - since nothing is clear with this boxplot, we shall try plotting them individually

# %%
df_num = df.select_dtypes(include='number')

# %%
fig, ax = plt.subplots(11, 4, figsize=(25, 8))

for variable, subplot in zip(df_num.columns, ax.flatten()):
    z = sns.boxplot(x = df_num[variable], orient = "h",whis=1.5 , ax=subplot)
    z.set_xlabel(variable, fontsize = 20)

# %% [markdown]
# - From the above boxplot, it can be seen that most of the numerical columns has outliers, hence we can fill our numerical cols with mean of that column.

# %%
df[num]=df[num].fillna(df.median())

# %%
Total = df.isnull().sum().sort_values(ascending=False) 
Percent = (df.isnull().sum()*100/df.isnull().count()).sort_values(ascending=False)   
missing_data = pd.concat([Total, Percent], axis = 1, keys = ['Total', 'Percentage of Missing Values'])
missing_data
# Out:
#                   Total  Percentage of Missing Values
# INT_ANY               0                           0.0
# summary               0                           0.0
# corp1                 0                           0.0
# targsubtype1_txt      0                           0.0
# targsubtype1          0                           0.0
# ...                 ...                           ...
# nperps                0                           0.0
# individual            0                           0.0
# guncertain1           0                           0.0
# motive                0                           0.0
# eventid               0                           0.0
#
# [67 rows x 2 columns]

# %% [markdown]
# - After handling null values we can see from the above table that there are no null values present, however we can visualize the same using the heatmap.

# %%
df[df['State']=='Unknown']
# Out:
# Empty DataFrame
# Columns: [eventid, Year, Month, day, extended, country, Country, region, Region, State, city, latitude, longitude, specificity, vicinity, location, summary, crit1, crit2, crit3, doubtterr, multiple, success, suicide, attacktype1, Attacktype, targtype1, Target_type, targsubtype1, targsubtype1_txt, corp1, target1, natlty1, natlty1_txt, Group, motive, guncertain1, individual, nperps, nperpcap, claimed, weaptype1, Weapon, weapsubtype1, weapsubtype1_txt, weapdetail, kill, nkillus, nkillter, Wound, nwoundus, nwoundte, property, propextent, propextent_txt, propvalue, propcomment, ishostkid, ransom, scite1, scite2, scite3, dbsource, INT_LOG, INT_IDEO, INT_MISC, INT_ANY]
# Index: []
#
# [0 rows x 67 columns]

# %% [markdown]
# - Now we can also infer that unknown values are also replace with mode.

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# - heatmap confirms that there are no missing values

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Distribution of each numeric variables

# %%
df.skew()
# Out:
# eventid          -0.619155
# Year             -0.619067
# Month             0.006750
# day               0.019065
# extended          4.370397
# country           3.152161
# region           -0.348260
# latitude         -0.999909
# longitude      -426.252222
# specificity       2.159575
# vicinity         -3.789433
# crit1            -9.175880
# crit2           -11.907267
# crit3            -2.277071
# doubtterr        -3.074592
# multiple          2.101954
# success          -2.486370
# suicide           4.942699
# attacktype1       1.546775
# targtype1         0.459817
# targsubtype1      0.495169
# natlty1           3.329175
# guncertain1       3.064849
# individual       18.329873
# nperps           68.986928
# nperpcap         -8.782324
# claimed          -8.864494
# weaptype1         2.243913
# weapsubtype1      0.208861
# kill             55.668242
# nkillus         282.704386
# nkillter         52.735293
# Wound           182.948092
# nwoundus        263.518411
# nwoundte         63.961527
# property         -2.272144
# propextent        2.116404
# propvalue       317.084208
# ishostkid       -12.604280
# ransom          -11.060284
# INT_LOG           0.042633
# INT_IDEO          0.053384
# INT_MISC        -10.495092
# INT_ANY          -0.137264
# dtype: float64

# %%
plt.figure(figsize=(25,10))
df.hist()
plt.show()

# %% [markdown]
# - using this plot we can say which variables are right skewed, left skewed and normally distributed.
# - from the above plot, we can say that there are few variables which are right skewed, few which are left skewed. However, there are variables which is normally distributed like Month,day,INT_LOG,INT_IDEO.

# %% [markdown]
# ### Checking for correlation between variables

# %%
plt.figure(figsize=(50,20))
sns.heatmap(df.corr(),annot=True,cmap='BuPu')
plt.show()

# %% [markdown]
# - A heatmap is plotted for checking correlation between variables.
# - if the color is in light blue shade, then the correlation is very low. If color is in blue-purple shade then the correlation is in the range 0.2-0.4, as the purple shade goes darker the correlation between the variables increases.
# - There are 2-3 variables which are correlated to each other

# %% [markdown]
# ### People Affected From Year 1970 - 2017

# %%
y_1970=df[df['kill']>0][['Year','kill','Wound']]
y_1970=y_1970.groupby(['Year'])[['kill','Wound']].sum()
y_1970.plot(kind='bar',stacked=True,figsize=(15,6))
plt.title('Population Affected From Year 1970 - 2017',fontsize=20,fontweight='bold')
plt.ylabel('Number of People',fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.xticks(rotation=50)
plt.grid()
plt.show()

# %% [markdown]
# - we can see that from the years 2014-2017 there were most of them who were either killed or wounded. However, in the inital years of our dataset from 1970-1982, there are not many people affected during this phase(less than 10000).

# %% [markdown]
# ### People Killed Year-Wise

# %%
ax = df.groupby(['Year'])['kill'].sum().sort_values(ascending = False).head(15).plot(kind = 'bar', colormap = 'jet')
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))
plt.title('Total Number of People Killed Year-Wise',fontsize=20,fontweight='bold')
plt.ylabel('Number of people killed', fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.xticks(rotation=30) 
plt.show()

# %% [markdown]
# - The above plot shows the total number of people killed each year, we can see that there were around 44,490 people killed in the year 2014 which records the most number of deaths.

# %% [markdown]
# ### Terrorist Activities By Region In Each Year

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',stacked=False)
plt.title('Terrorist Activities By Region In Each Year',fontsize=20,fontweight='bold')
plt.ylabel('Number of Attacks',fontsize=15)
plt.xlabel('Year',fontsize=15)
plt.show()

# %% [markdown]
# - from the above area plot, we can see that Middle East and North Africa region accounted for most number of attacks after 2010. This region is followed by South Asia during the same period of time.

# %% [markdown]
# ### Number of Attacks Month-Wise

# %%
ax = sns.barplot(x = df["Month"].value_counts()[:20].index, y=df["Month"].value_counts()[:20].values
                ,order = df['Month'].value_counts().index,palette='PuBu_r',saturation=0.8)
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))
    
plt.title('Total Number of Attacks Month-Wise', fontsize=20,fontweight='bold')
plt.ylabel('Number of Attacks', fontsize=15)
plt.xlabel('Month', fontsize=15)
plt.show()

# %% [markdown]
# - From the above plot we can infer that, mostly there are most number of attacks in the month of May which has around 16875 attacks in total. This is followed by July which has around 16268 number of attacks in total.
# - Comparitevely, there are less number of attacks in the month of December.

# %% [markdown]
# ### Number of Attacks in Each Country

# %%
ax = sns.barplot(x = df["Country"].value_counts()[:20].index, y=df["Country"].value_counts()[:20].values)
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))
    
plt.title("Total Number of Attacks Country-Wise", size=20,fontweight='bold')
plt.ylabel("Number of Attacks", fontsize=15)
plt.xlabel("Region", fontsize=15)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# - From the above plot, we can infer that Iraq has the most number of attacks with 24636 number of attacks in total.

# %% [markdown]
# ### Number of Attacks in Each State

# %%
ax = df['State'].value_counts().to_frame().sort_values('State',axis=0,ascending=False).head(10).plot(kind='bar',color='slateblue')
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))

plt.title("Total Number of Attacks For Top 10 States",fontsize=20)
plt.ylabel("Number of attacks",fontsize=15)
plt.xlabel("State",fontsize=15)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - From the above plot we can infer that, Baghdad has most number of attacks as compared with other states. It has around 12356 number of attacks while the second highest has around 4498 number of attacks. Hence we can say that Baghdad State is the most affected state

# %% [markdown]
# ### Number of Attacks in Each City

# %%
ax = df['city'].value_counts().to_frame().sort_values('city',axis=0,ascending=False).head(10).plot(kind='bar',color='teal')
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))
    
plt.title("Total Number of Attacks For Top 10 Cities",fontsize=20,fontweight='bold')
plt.ylabel("Number of attack",fontsize=15)
plt.xlabel("City",fontsize=15)
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# - From the above plot we can infer that, Baghdad has most number of attacks as compared with other cities. It has around 17798 number of attacks while the second highest has around 2652 number of attacks. Hence we can say that Baghdad State is the most affected City

# %% [markdown]
# ### Number of Attacks in Each Region

# %%
ax = df['Region'].value_counts().to_frame().sort_values('Region',axis=0,ascending=False).head(10).plot(kind='bar',color='darkslateblue')
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))

plt.title("Total Number of Attacks For Top 10 Regions",fontsize=20,fontweight='bold')
plt.ylabel("Number of Attacks",fontsize=15)
plt.xlabel("Region",fontsize=15)
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# - from the above area plot, we can see that Middle East and North Africa region accounted for most number of attacks that is 50474. This region is followed by South Asia with 44974 number of attacks.

# %% [markdown]
# ### Attack Type

# %%
count = df['Attacktype'].value_counts()
ax = sns.countplot(df['Attacktype'],order = count.index,palette='Paired')
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))
    
plt.title("Attack Type",fontsize=20,fontweight='bold')
plt.ylabel("Number of Attacks",fontsize=15)
plt.xlabel("Type of Attack",fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - From the above plot, we can infer that Bombing/Explosion is the most widely used attack type for terrorism.

# %% [markdown]
# ### Weapon Type

# %%
plt.figure(figsize=(12,6))
count = df['Weapon'].value_counts()[:5]
ax = sns.countplot(df['Weapon'],order = count.index,palette='Dark2')
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))

plt.title("Weapon Type",fontsize=20,fontweight='bold')
plt.ylabel("Number of Attacks",fontsize=15)
plt.xlabel('Type of Weapon')
plt.show()

# %% [markdown]
# - From the above plot it is quite evident that explosives was mostly used as a weapon for attacking which was followed by Firearms.Chemicals were rarely used to attack.

# %% [markdown]
# ### Target Type

# %%
plt.figure(figsize=(12,6))
count = df['Target_type'].value_counts()[:5]
ax = sns.countplot(df['Target_type'],order = count.index,color='indigo')
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))

plt.title("Target Type",fontsize=20,fontweight='bold')
plt.ylabel("Number of Attacks",fontsize=15)
plt.xlabel('Type of Target')
plt.show()

# %% [markdown]
# - From the above plot it is quite evident that the terrorists targeted mostly Private citizens and Property type, followed by Military group

# %% [markdown]
# ### Attack Group

# %%
ax = sns.barplot(x = df["Group"].value_counts()[:20].index, y=df["Group"].value_counts()[:20].values)
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))
    
plt.title("Total Number of Attacks By Each Attack Group", size=20, fontweight="bold")
plt.ylabel("Number of Attacks", fontsize=15)
plt.xlabel("Group Name", fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - from the above barplot, we can clearly say that Taliban is the terrorism group that is performing most number of attacks which has done around 90260 number of attacks while the second most is Islamic State of Iraq and the levant group with 5613 number of attacks.

# %% [markdown]
# ### Number of People Killed By Each Country and Terrorist Group

# %%
df_1=df[['Group','Country','kill']]
df_1=df_1.groupby(['Group','Country'],axis=0).sum().sort_values('kill',ascending=False).reset_index().head(10)
df_1
# Out:
#                                               Group      Country     kill
# 0                                           Taliban         Iraq  38560.0
# 1                                           Taliban  Afghanistan  36667.0
# 2       Islamic State of Iraq and the Levant (ISIL)         Iraq  31058.0
# 3                                        Boko Haram      Nigeria  16917.0
# 4                                           Taliban     Pakistan  12161.0
# 5                                 Shining Path (SL)         Peru  11595.0
# 6           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 7                                        Al-Shabaab      Somalia   8176.0
# 8  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 9       Islamic State of Iraq and the Levant (ISIL)        Syria   6883.0

# %%
ax = sns.barplot(x = 'Group',y = 'kill',hue='Country',data = df_1)
for p in ax.patches:                 
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+100))

plt.title('Total Number Of People Killed By Each Country And Each Terrorist Group',size=20, fontweight="bold")
plt.ylabel('Number of People killed', fontsize=15)
plt.xlabel('Terrorist Group Name', fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - from the above plot, we can say that taliban has performed most number of attacks on Iraq, Afganisthan and Pakistan

# %%
countryKill = df.pivot_table(columns='Country', values='kill', aggfunc='sum')
countryKill
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# kill         39384.0     42.0  11066.0      0.0  3043.0                  0.0
#
# Country  Argentina  Armenia  Australia  Austria  ...  Vietnam  \
# kill         490.0     37.0       23.0     30.0  ...      1.0
#
# Country  Wallis and Futuna  West Bank and Gaza Strip  West Germany (FRG)  \
# kill                   0.0                    1500.0                97.0
#
# Country  Western Sahara   Yemen  Yugoslavia  Zaire  Zambia  Zimbabwe
# kill                1.0  8776.0       119.0  324.0    70.0     154.0
#
# [1 rows x 205 columns]

# %% [markdown]
# - Conclusion :
#     - We found that hot zone for terrorism is Iraq.
#     - Baghdad state and city has the most number of terrorist attacks.
#     - 2014 is the year which accounted for most number of terrorist attacks.
#     - explosives was used as a weapon for terrorism.
#     - Taliban group has done the most number of attacks.
#     - Private Citizens and Properties were the most targeted type for terrorism.
#     - Afghanistan is the country were most of the people were killed due to terrorism.
